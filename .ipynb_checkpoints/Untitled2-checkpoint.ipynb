# %%
import requests
import json as js

# %%
def getRec(json):
    if( json['next'] != None ):
        url = json['next']
        resp = requests.get(url, verify = False)
        next=resp.json()
        json['results'].extend(next['results'])
        json['previous']=next['previous']
        json['next']=next['next']
        getRec(json)
    return json

# %%
url = "https://swapi.dev/api/people/"

resp = requests.get(url, verify = False)
resp
peopleJson=resp.json()
peopleJson=getRec(peopleJson)
peopleJson["results"]

#Creating json string
jsonString = js.dumps(peopleJson["results"], indent=4)
#print(jsonString)
#print(type(jsonString))
# Out:
# /home/administrator/anaconda3/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:730: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   warnings.warn((
# /home/administrator/anaconda3/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:730: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   warnings.warn((
# /home/administrator/anaconda3/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:730: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   warnings.warn((
# ...

# %%
#Creating json string
jsonString = js.dumps(peopleJson["results"], indent=4)
#print(jsonString)
#print(type(jsonString))

# %%
with open("people.json", "w") as outfile:
    outfile.write(jsonString)

# %%
url = "https://swapi.dev/api/films"
resp = requests.get(url, verify = False)
filmsJson=resp.json()
filmsJson=getRec(filmsJson)
filmsJson["results"]
jsonString = js.dumps(filmsJson["results"], indent=4)
print(jsonString)
#print(type(jsonString))
# Out:
# /home/administrator/anaconda3/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:730: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   warnings.warn((
# [
#     {
#         "title": "A New Hope",
#         "episode_id": 4,
#         "opening_crawl": "It is a period of civil war.\r\nRebel spaceships, striking\r\nfrom a hidden base, have won\r\ntheir first victory against\r\nthe evil Galactic Empire.\r\n\r\nDuring the battle, Rebel\r\nspies managed to steal secret\r\nplans to the Empire's\r\nultimate weapon, the DEATH\r\nSTAR, an armored space\r\nstation with enough power\r\nto destroy an entire planet.\r\n\r\nPursued by the Empire's\r\nsinister agents, Princess\r\nLeia races home aboard her\r\nstarship, custodian of the\r\nstolen plans that can save her\r\npeople and restore\r\nfreedom to the galaxy....",
# ...

# %%
with open("films.json", "w") as outfile:
    outfile.write(jsonString)

# %%
#json["results"]

# %%
data=[]
for id,result in enumerate(peopleJson["results"]):
    #print(idx)
    #print(json["results"][id]["films"])
    for film in peopleJson["results"][id]["films"]:
        #out+='"film":"'+film+'","person":"'+json["results"][id]["url"]+'",' 
        dict={"film":film,"person":peopleJson["results"][id]["url"]}
        data.append(dict)
#data
jsonString = js.dumps(data, indent=4)
print(jsonString)
#out
#print(out)
#d = js.loads(out)
#d
# Out:
# [
#     {
#         "film": "https://swapi.dev/api/films/1/",
#         "person": "https://swapi.dev/api/people/1/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/2/",
#         "person": "https://swapi.dev/api/people/1/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/3/",
#         "person": "https://swapi.dev/api/people/1/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/6/",
#         "person": "https://swapi.dev/api/people/1/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/1/",
#         "person": "https://swapi.dev/api/people/2/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/2/",
#         "person": "https://swapi.dev/api/people/2/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/3/",
#         "person": "https://swapi.dev/api/people/2/"
#     },
#     {
#         "film": "https://swapi.dev/api/films/4/",
#         "person": "https://swapi.dev/api/people/2/"
#     },
#     {
# ...

# %%
with open("personFilm.json", "w") as outfile:
    outfile.write(jsonString)
